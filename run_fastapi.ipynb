# %% [markdown]
# # Run FastAPI

# %%
# !uvicorn chatbot-backend.main:app --reload
# Out:
# INFO:     Will watch for changes in these directories: ['/home/weiyanpeh/Git/chatbot_test']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [14733] using StatReload
# INFO:     Started server process [14737]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:36090 - "OPTIONS /chat HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36090 - "POST /chat HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36096 - "POST /chat HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36102 - "POST /chat HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36102 - "POST /chat HTTP/1.1" 500 Internal Server Error
# INFO:     127.0.0.1:36102 - "POST /chat HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36102 - "POST /chat HTTP/1.1" 500 Internal Server Error
# WARNING:  StatReload detected changes in 'chatbot-backend/main.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# ...
