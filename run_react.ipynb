# %% [markdown]
# # Website
# https://dev.to/vipascal99/building-a-full-stack-ai-chatbot-with-fastapi-backend-and-react-frontend-51ph

# %% [markdown]
# # Create Project

# %%
# Create a new React project
# !npm create vite@latest chatbot-frontend --template react

# %%
ls
# Out:
# __pycache__/  build_react.ipynb  chatbot-backend/  chatbot-frontend/  run.ipynb

# %%
# Out:
# /home/weiyanpeh/Git/chatbot_test/chatbot-frontend

# %% [markdown]
# # Run NPM

# %%
cd chatbot-frontend/
# Out:
# /home/weiyanpeh/Git/chatbot_test/chatbot-frontend

# %%
# !npm run dev
# Out:
# > chatbot-frontend@0.0.0 dev
# > vite
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   VITE v7.1.12  ready in 140 ms
#
#   ➜  Local:   http://localhost:5173/
#   ➜  Network: use --host to expose
#   ➜  press h + enter to show help
# ^C
